# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import recall_score,r2_score,mean_absolute_error,mean_squared_error,roc_auc_score,roc_curve,f1_score,precision_score,accuracy_score
from statsmodels.api import OLS
import pickle

# %%
df = pd.read_csv('winequality_red - winequality_red.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            NaN               NaN          NaN             NaN        NaN
# 1            7.4              0.70          0.0             1.9      0.076
# 2            NaN               NaN          NaN             NaN        NaN
# 3            7.8              0.88          0.0             2.6      0.098
# 4            NaN               NaN          NaN             NaN        NaN
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                  NaN                   NaN      NaN   NaN        NaN
# 1                 11.0                  34.0   0.9978  3.51       0.56
# 2                  NaN                   NaN      NaN   NaN        NaN
# 3                 25.0                  67.0   0.9968  3.20       0.68
# 4                  NaN                   NaN      NaN   NaN        NaN
#
#    alcohol  quality
# 0      NaN      NaN
# 1      9.4      5.0
# 2      NaN      NaN
# ...

# %%
df.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 3193            6.3             0.510         0.13             2.3      0.076
# 3194            NaN               NaN          NaN             NaN        NaN
# 3195            5.9             0.645         0.12             2.0      0.075
# 3196            NaN               NaN          NaN             NaN        NaN
# 3197            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 3193                 29.0                  40.0  0.99574  3.42       0.75
# 3194                  NaN                   NaN      NaN   NaN        NaN
# 3195                 32.0                  44.0  0.99547  3.57       0.71
# 3196                  NaN                   NaN      NaN   NaN        NaN
# 3197                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 3193     11.0      6.0
# ...

# %%
df.dropna(inplace=True)

df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1            7.4              0.70         0.00             1.9      0.076
# 3            7.8              0.88         0.00             2.6      0.098
# 5            7.8              0.76         0.04             2.3      0.092
# 7           11.2              0.28         0.56             1.9      0.075
# 9            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1                 11.0                  34.0   0.9978  3.51       0.56
# 3                 25.0                  67.0   0.9968  3.20       0.68
# 5                 15.0                  54.0   0.9970  3.26       0.65
# 7                 17.0                  60.0   0.9980  3.16       0.58
# 9                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 1      9.4      5.0
# 3      9.8      5.0
# 5      9.8      5.0
# ...

# %%
df.shape
# Out:
# (1599, 12)

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                 float64
# dtype: object

# %%
X=df.drop('quality',axis=1)
y=df['quality']

# %%
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1               7.4             0.700         0.00             1.9      0.076
# 3               7.8             0.880         0.00             2.6      0.098
# 5               7.8             0.760         0.04             2.3      0.092
# 7              11.2             0.280         0.56             1.9      0.075
# 9               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 3189            6.2             0.600         0.08             2.0      0.090
# 3191            5.9             0.550         0.10             2.2      0.062
# 3193            6.3             0.510         0.13             2.3      0.076
# 3195            5.9             0.645         0.12             2.0      0.075
# 3197            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1               7.4             0.700         0.00             1.9      0.076
# 3               7.8             0.880         0.00             2.6      0.098
# 5               7.8             0.760         0.04             2.3      0.092
# 7              11.2             0.280         0.56             1.9      0.075
# 9               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 3189            6.2             0.600         0.08             2.0      0.090
# 3191            5.9             0.550         0.10             2.2      0.062
# 3193            6.3             0.510         0.13             2.3      0.076
# 3195            5.9             0.645         0.12             2.0      0.075
# 3197            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
y
# Out:
# 1       5.0
# 3       5.0
# 5       5.0
# 7       6.0
# 9       5.0
#        ...
# 3189    5.0
# 3191    6.0
# 3193    6.0
# 3195    5.0
# 3197    6.0
# Name: quality, Length: 1599, dtype: float64

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=54,test_size=0.3)

# %%
X_train
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 3015            7.5              0.38         0.57             2.3      0.106
# 1573            9.9              0.35         0.41             2.3      0.083
# 2723            8.3              0.85         0.14             2.5      0.093
# 761             8.3              0.26         0.42             2.0      0.080
# 2077            8.7              0.41         0.41             6.2      0.078
# ...             ...               ...          ...             ...        ...
# 2689           11.5              0.42         0.48             2.6      0.077
# 2095            7.1              0.43         0.17             1.8      0.082
# 1797            8.3              0.31         0.39             2.4      0.078
# 2699            6.9              0.57         0.00             2.8      0.081
# 2271            8.0              0.25         0.43             1.7      0.067
#
# ...

# %%
X_test
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 185             8.6             0.490         0.29             2.0      0.110
# 1317            7.2             0.520         0.07             1.4      0.074
# 971            10.2             0.670         0.39             1.9      0.054
# 647            10.3             0.590         0.42             2.8      0.090
# 2131            7.7             0.610         0.18             2.4      0.083
# ...             ...               ...          ...             ...        ...
# 2827            9.9             0.570         0.25             2.0      0.104
# 3103            7.1             0.670         0.00             2.3      0.083
# 449             8.4             0.635         0.36             2.0      0.089
# 1953            7.2             0.410         0.30             2.1      0.083
# 1227            8.2             0.390         0.38             1.5      0.058
#
# ...

# %%
y_train
# Out:
# 3015    6.0
# 1573    5.0
# 2723    5.0
# 761     6.0
# 2077    7.0
#        ...
# 2689    5.0
# 2095    5.0
# 1797    7.0
# 2699    5.0
# 2271    6.0
# Name: quality, Length: 1119, dtype: float64

# %%
y_test
# Out:
# 185     5.0
# 1317    6.0
# 971     5.0
# 647     6.0
# 2131    6.0
#        ...
# 2827    5.0
# 3103    5.0
# 449     4.0
# 1953    5.0
# 1227    5.0
# Name: quality, Length: 480, dtype: float64

# %%
X_train.shape,y_train.shape
# Out:
# ((1119, 11), (1119,))

# %%
X_test.shape,y_test.shape
# Out:
# ((480, 11), (480,))

# %%
X_train.ndim
# Out:
# 2

# %%
y_train.ndim
# Out:
# 1

# %%
type(X_train)
# Out:
# pandas.core.frame.DataFrame

# %%
LR=LinearRegression()

# %%
LR.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=LR.predict(X_test)

# %%
y_test,y_pred
# Out:
# (185     5.0
#  1317    6.0
#  971     5.0
#  647     6.0
#  2131    6.0
#         ...
#  2827    5.0
#  3103    5.0
#  449     4.0
#  1953    5.0
#  1227    5.0
#  Name: quality, Length: 480, dtype: float64,
#  array([6.49547225, 5.60898678, 5.30042804, 5.30216512, 5.47641876,
#         5.74795131, 5.08020387, 4.92432241, 5.60455338, 5.82819723,
#         5.85180217, 5.24243551, 6.27233396, 6.35575663, 6.32139756,
#         5.09321294, 6.15721502, 5.42856932, 5.97317773, 6.40570244,
#         6.51243394, 5.46866418, 6.13759167, 6.20720944, 5.49895607,
#         5.99019631, 5.45850918, 6.6475348 , 5.52614297, 5.69949741,
#         6.17784282, 6.01768175, 5.03246039, 5.71204648, 6.86362687,
#         6.22817325, 5.59192534, 6.1635507 , 4.96929034, 5.34955645,
#         5.39690127, 6.45538231, 5.12298982, 5.99335474, 5.09514614,
#         5.03125379, 5.42041842, 5.88363866, 5.50946259, 4.98512163,
#         5.33054214, 5.2033026 , 5.93108859, 6.24003271, 6.28337327,
# ...

# %%
y_pred.shape,y_test.shape
# Out:
# ((480,), (480,))

# %%
X_test.iloc[0]
# Out:
# fixed acidity             8.6000
# volatile acidity          0.4900
# citric acid               0.2900
# residual sugar            2.0000
# chlorides                 0.1100
# free sulfur dioxide      19.0000
# total sulfur dioxide    133.0000
# density                   0.9972
# pH                        2.9300
# sulphates                 1.9800
# alcohol                   9.8000
# Name: 185, dtype: float64

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.3590193156405148

# %%
r2_score(y_test,y_pred)
# Out:
# 0.3590193156405148

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 0.5045715081842412

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 0.4250920468291882

# %%
LR.coef_
# Out:
# array([ 1.44546883e-02, -1.28410149e+00, -3.02185075e-01,  8.28574898e-03,
#        -1.57830044e+00,  4.37558640e-03, -3.02183713e-03, -4.91206644e+00,
#        -4.35742504e-01,  8.53474324e-01,  2.86337945e-01])

# %%
LR.intercept_
# Out:
# 9.242862250948647
